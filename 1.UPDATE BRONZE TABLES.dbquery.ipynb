-- %%
CREATE OR REPLACE TABLE jovi_lakehouse.bronze.vendas AS
SELECT *
FROM jovi_database_aws_catalog.jovi_norte.vendas;

CREATE OR REPLACE TABLE jovi_lakehouse.bronze.promotores AS
SELECT *
FROM jovi_database_aws_catalog.jovi_norte.promotores;

CREATE OR REPLACE TABLE jovi_lakehouse.bronze.lojas AS
SELECT *
FROM jovi_database_aws_catalog.jovi_norte.lojas;

CREATE OR REPLACE TABLE jovi_lakehouse.bronze.produtos AS
SELECT *
FROM jovi_database_aws_catalog.jovi_norte.produtos;

CREATE OR REPLACE TABLE jovi_lakehouse.bronze.supervisores AS
SELECT *
FROM jovi_database_aws_catalog.jovi_norte.supervisores;

CREATE OR REPLACE TABLE jovi_lakehouse.bronze.metas AS
SELECT *
FROM jovi_database_aws_catalog.jovi_norte.metas;
